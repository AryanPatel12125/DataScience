# %%
# %pip install scikit-learn numpy pandas
# Out:
# ...
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/60.4 kB 1.3 MB/s eta 0:00:01
#      ---------------------------------------- 60.4/60.4 kB 1.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.6 MB 2.6 MB/s eta 0:00:05
#    - -------------------------------------- 0.4/11.6 MB 3.7 MB/s eta 0:00:04
#    -- ------------------------------------- 0.7/11.6 MB 4.8 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.2/11.6 MB 6.6 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.5/11.6 MB 7.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.7/11.6 MB 6.3 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.7/11.6 MB 6.3 MB/s eta 0:00:02
#    --------- ------------------------------ 2.7/11.6 MB 7.5 MB/s eta 0:00:02
# ...
