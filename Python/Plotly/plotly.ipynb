711774418495,0.3534449185593571,0.7069597721247556,0.04021563428605135,0.9032023309462952,0.7562430634966306,0.3413325745013015,0.024079058761476868,0.8231700221998317,0.39058785659291806,0.7186828100147218,0.7696317126523814,0.862928029049044,0.2727065701468454,0.7389343463481224,0.8008559997004039,0.8997279229128132,0.2646354239628478,0.23131057722860915,0.4154062957997309,0.24275891445713804,0.3840081893974313,0.13233654342471657,0.35782341683348495,0.9729176149456534,0.094318180060061 ...

# %%
# !pip install tabpy
# Out:
# Collecting tabpy
#   Downloading tabpy-2.9.0.tar.gz (461 kB)
#      -------------------------------------- 461.8/461.8 kB 9.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: cloudpickle in g:\anaconda\lib\site-packages (from tabpy) (2.0.0)
# Collecting configparser
#   Downloading configparser-6.0.0-py3-none-any.whl (19 kB)
# Collecting coverage
#   Downloading coverage-7.3.2-cp310-cp310-win_amd64.whl (203 kB)
#      ---------------------------------------- 203.2/203.2 kB ? eta 0:00:00
# Collecting coveralls
#   Downloading coveralls-3.3.1-py2.py3-none-any.whl (14 kB)
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: future in g:\anaconda\lib\site-packages (from tabpy) (0.18.3)
# Collecting genson
#   Downloading genson-1.2.2.tar.gz (34 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting hypothesis
#   Downloading hypothesis-6.87.3-py3-none-any.whl (420 kB)
#      -------------------------------------- 420.8/420.8 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema in g:\anaconda\lib\site-packages (from tabpy) (4.17.3)
# Requirement already satisfied: mock in g:\anaconda\lib\site-packages (from tabpy) (4.0.3)
# Requirement already satisfied: nltk in g:\anaconda\lib\site-packages (from tabpy) (3.7)
# Requirement already satisfied: numpy in g:\anaconda\lib\site-packages (from tabpy) (1.23.5)
# Requirement already satisfied: pandas in g:\anaconda\lib\site-packages (from tabpy) (1.5.3)
# Requirement already satisfied: pyopenssl in g:\anaconda\lib\site-packages (from tabpy) (23.0.0)
# Requirement already satisfied: pytest in g:\anaconda\lib\site-packages (from tabpy) (7.1.2)
# Collecting pytest-cov
#   Downloading pytest_cov-4.1.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: requests in g:\anaconda\lib\site-packages (from tabpy) (2.28.1)
# Requirement already satisfied: scipy in g:\anaconda\lib\site-packages (from tabpy) (1.10.0)
# Collecting simplejson
#   Downloading simplejson-3.19.2-cp310-cp310-win_amd64.whl (75 kB)
#      ---------------------------------------- 75.5/75.5 kB ? eta 0:00:00
# Requirement already satisfied: scikit-learn in g:\anaconda\lib\site-packages (from tabpy) (1.2.1)
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      -------------------------------------- 636.8/636.8 kB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: tornado in g:\anaconda\lib\site-packages (from tabpy) (6.1)
# Requirement already satisfied: twisted in g:\anaconda\lib\site-packages (from tabpy) (22.2.0)
# Requirement already satisfied: urllib3 in g:\anaconda\lib\site-packages (from tabpy) (1.26.14)
# Collecting pyarrow
#   Downloading pyarrow-13.0.0-cp310-cp310-win_amd64.whl (24.3 MB)
#      ---------------------------------------- 24.3/24.3 MB 9.2 MB/s eta 0:00:00
# Collecting coverage
#   Downloading coverage-6.5.0-cp310-cp310-win_amd64.whl (188 kB)
#      -------------------------------------- 188.5/188.5 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in g:\anaconda\lib\site-packages (from requests->tabpy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in g:\anaconda\lib\site-packages (from requests->tabpy) (2023.7.22)
# Requirement already satisfied: charset-normalizer<3,>=2 in g:\anaconda\lib\site-packages (from requests->tabpy) (2.1.1)
# Collecting exceptiongroup>=1.0.0
#   Downloading exceptiongroup-1.1.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: sortedcontainers<3.0.0,>=2.1.0 in g:\anaconda\lib\site-packages (from hypothesis->tabpy) (2.4.0)
# Requirement already satisfied: attrs>=19.2.0 in g:\anaconda\lib\site-packages (from hypothesis->tabpy) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in g:\anaconda\lib\site-packages (from jsonschema->tabpy) (0.18.0)
# Requirement already satisfied: tqdm in g:\anaconda\lib\site-packages (from nltk->tabpy) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in g:\anaconda\lib\site-packages (from nltk->tabpy) (2022.7.9)
# Requirement already satisfied: joblib in g:\anaconda\lib\site-packages (from nltk->tabpy) (1.1.1)
# Requirement already satisfied: click in g:\anaconda\lib\site-packages (from nltk->tabpy) (8.0.4)
# Requirement already satisfied: pytz>=2020.1 in g:\anaconda\lib\site-packages (from pandas->tabpy) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in g:\anaconda\lib\site-packages (from pandas->tabpy) (2.8.2)
# Requirement already satisfied: cryptography<40,>=38.0.0 in g:\anaconda\lib\site-packages (from pyopenssl->tabpy) (39.0.1)
# Requirement already satisfied: iniconfig in g:\anaconda\lib\site-packages (from pytest->tabpy) (1.1.1)
# Requirement already satisfied: packaging in g:\anaconda\lib\site-packages (from pytest->tabpy) (22.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in g:\anaconda\lib\site-packages (from pytest->tabpy) (1.0.0)
# Requirement already satisfied: py>=1.8.2 in g:\anaconda\lib\site-packages (from pytest->tabpy) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in g:\anaconda\lib\site-packages (from pytest->tabpy) (2.0.1)
# Requirement already satisfied: atomicwrites>=1.0 in g:\anaconda\lib\site-packages (from pytest->tabpy) (1.4.0)
# Requirement already satisfied: colorama in g:\anaconda\lib\site-packages (from pytest->tabpy) (0.4.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in g:\anaconda\lib\site-packages (from scikit-learn->tabpy) (2.2.0)
# Requirement already satisfied: constantly>=15.1 in g:\anaconda\lib\site-packages (from twisted->tabpy) (15.1.0)
# Requirement already satisfied: twisted-iocpsupport<2,>=1.0.2 in g:\anaconda\lib\site-packages (from twisted->tabpy) (1.0.2)
# Requirement already satisfied: zope.interface>=4.4.2 in g:\anaconda\lib\site-packages (from twisted->tabpy) (5.4.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in g:\anaconda\lib\site-packages (from twisted->tabpy) (4.4.0)
# Requirement already satisfied: hyperlink>=17.1.1 in g:\anaconda\lib\site-packages (from twisted->tabpy) (21.0.0)
# Requirement already satisfied: Automat>=0.8.0 in g:\anaconda\lib\site-packages (from twisted->tabpy) (20.2.0)
# Requirement already satisfied: incremental>=21.3.0 in g:\anaconda\lib\site-packages (from twisted->tabpy) (21.3.0)
# Requirement already satisfied: six in g:\anaconda\lib\site-packages (from Automat>=0.8.0->twisted->tabpy) (1.16.0)
# Collecting coverage[toml]>=5.2.1
#   Downloading coverage-7.3.1-cp310-cp310-win_amd64.whl (204 kB)
#      ------------------------------------- 204.5/204.5 kB 12.9 MB/s eta 0:00:00
#   Downloading coverage-7.3.0-cp310-cp310-win_amd64.whl (204 kB)
#      ------------------------------------- 204.4/204.4 kB 12.9 MB/s eta 0:00:00
#   Downloading coverage-7.2.7-cp310-cp310-win_amd64.whl (204 kB)
#      ------------------------------------- 204.1/204.1 kB 12.9 MB/s eta 0:00:00
#   Downloading coverage-7.2.6-cp310-cp310-win_amd64.whl (204 kB)
#      ------------------------------------- 204.1/204.1 kB 12.9 MB/s eta 0:00:00
#   Downloading coverage-7.2.5-cp310-cp310-win_amd64.whl (203 kB)
#      ------------------------------------- 203.6/203.6 kB 12.9 MB/s eta 0:00:00
#   Downloading coverage-7.2.4-cp310-cp310-win_amd64.whl (203 kB)
#      ------------------------------------- 203.5/203.5 kB 12.1 MB/s eta 0:00:00
#   Downloading coverage-7.2.3-cp310-cp310-win_amd64.whl (203 kB)
#      ------------------------------------- 203.4/203.4 kB 12.1 MB/s eta 0:00:00
#   Downloading coverage-7.2.2-cp310-cp310-win_amd64.whl (202 kB)
#      ------------------------------------- 202.9/202.9 kB 12.0 MB/s eta 0:00:00
#   Downloading coverage-7.2.1-cp310-cp310-win_amd64.whl (202 kB)
#      -------------------------------------- 202.7/202.7 kB 6.2 MB/s eta 0:00:00
#   Downloading coverage-7.2.0-cp310-cp310-win_amd64.whl (202 kB)
#      ------------------------------------- 202.7/202.7 kB 12.0 MB/s eta 0:00:00
#   Downloading coverage-7.1.0-cp310-cp310-win_amd64.whl (202 kB)
#      ------------------------------------- 202.0/202.0 kB 12.0 MB/s eta 0:00:00
#   Downloading coverage-7.0.5-cp310-cp310-win_amd64.whl (201 kB)
#      -------------------------------------- 201.3/201.3 kB 6.2 MB/s eta 0:00:00
#   Downloading coverage-7.0.4-cp310-cp310-win_amd64.whl (200 kB)
#      -------------------------------------- 200.7/200.7 kB 6.0 MB/s eta 0:00:00
#   Downloading coverage-7.0.3-cp310-cp310-win_amd64.whl (200 kB)
#      ------------------------------------- 200.2/200.2 kB 12.7 MB/s eta 0:00:00
#   Downloading coverage-7.0.2-cp310-cp310-win_amd64.whl (199 kB)
#      -------------------------------------- 199.8/199.8 kB 5.9 MB/s eta 0:00:00
#   Downloading coverage-7.0.1-cp310-cp310-win_amd64.whl (191 kB)
#      ------------------------------------- 191.3/191.3 kB 12.1 MB/s eta 0:00:00
#   Downloading coverage-7.0.0-cp310-cp310-win_amd64.whl (191 kB)
#      ------------------------------------- 191.2/191.2 kB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: cffi>=1.12 in g:\anaconda\lib\site-packages (from cryptography<40,>=38.0.0->pyopenssl->tabpy) (1.15.1)
# Requirement already satisfied: setuptools in g:\anaconda\lib\site-packages (from zope.interface>=4.4.2->twisted->tabpy) (65.6.3)
# Requirement already satisfied: pycparser in g:\anaconda\lib\site-packages (from cffi>=1.12->cryptography<40,>=38.0.0->pyopenssl->tabpy) (2.21)
# Building wheels for collected packages: tabpy, docopt, genson
#   Building wheel for tabpy (setup.py): started
#   Building wheel for tabpy (setup.py): finished with status 'done'
#   Created wheel for tabpy: filename=tabpy-2.9.0-py2.py3-none-any.whl size=119178 sha256=08de72f6d024f05d7c39c525c7f3dcdba5f50f9ca2ae3411808f1881d426d28f
#   Stored in directory: c:\users\aryan\appdata\local\pip\cache\wheels\4b\c6\cf\ff907e97f8805a8d81d0df99726f4cd65139f9bc375068b350
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13775 sha256=d2b730c023bfd22ad86d41e2d7e0b48d7900e7c62b484220a6013515ea151fe6
#   Stored in directory: c:\users\aryan\appdata\local\pip\cache\wheels\7c\d7\8d\2156234738063e3d4a39ba77dc677046100e62766b53807189
#   Building wheel for genson (setup.py): started
#   Building wheel for genson (setup.py): finished with status 'done'
#   Created wheel for genson: filename=genson-1.2.2-py2.py3-none-any.whl size=21330 sha256=b279e5696d1d9b32983605a6ff0f1057bf23f6fd45b6d78025d3fdc26d830a1c
#   Stored in directory: c:\users\aryan\appdata\local\pip\cache\wheels\de\01\b4\410fc7873803601c177cd4a2694b1b161edf07f350dcfaf5c6
# Successfully built tabpy docopt genson
# Installing collected packages: genson, docopt, simplejson, pyarrow, exceptiongroup, coverage, configparser, hypothesis, coveralls, textblob, pytest-cov, tabpy
# Successfully installed configparser-6.0.0 coverage-6.5.0 coveralls-3.3.1 docopt-0.6.2 exceptiongroup-1.1.3 genson-1.2.2 hypothesis-6.87.3 pyarrow-13.0.0 pytest-cov-4.1.0 simplejson-3.19.2 tabpy-2.9.0 textblob-0.17.1
# Note: you may need to restart the kernel to use updated packages.
